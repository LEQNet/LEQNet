# %%
# %reload_ext autoreload
# %autoreload 2

# EqT_utils.py 내의 _encoder, _decoder, cred2 modified

from LEQNet.core.trainer import trainer
trainer(input_hdf5='../data/STEAD/merge_modified.hdf5',
        input_csv='../data/STEAD/mix_train_merge_modified.csv',
        output_name='LEQNet_test_trainer',
        cnn_blocks=4,
        lstm_blocks=2,
        padding='same',
        activation='relu',
        label_type='gaussian',
        mode='generator',
        train_valid_test_split=[0.80, 0.10, 0.10],
        batch_size=20,
        epochs=10, 
        patience=2
       )
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# separable_conv1d_1 (SeparableCo (None, 6000, 8)      65          input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 2000, 8)      0           separable_conv1d_1[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_2 (SeparableCo (None, 2000, 16)     216         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# %reload_ext autoreload
from LEQNet.core.tester import model_load
import sys

model = model_load(input_hdf5='../data/STEAD/merge_modified.hdf5',
       input_testset='LEQNet_test_trainer_outputs/test.npy',
       input_model='LEQNet_test_trainer_outputs/final_model.h5',
       output_name='LEQNet_test_tester',
       detection_threshold=0.50,                
       P_threshold=0.3,
       S_threshold=0.3, 
       number_of_plots=3,
       estimate_uncertainty=False, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)

sys.getsizeof(model)
# Out:
# Using TensorFlow backend.
# Loading the model ...!
# 56
